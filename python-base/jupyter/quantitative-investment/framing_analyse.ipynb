# %%
import pymysql
import pyecharts
from pyecharts import options as opts
from pyecharts.charts import Page,Bar,Map,Line,WordCloud

# %%
def get_cursor(sql): 
    # 连接数据库
    connect = pymysql.Connect(host='localhost', port=3306, user='root', passwd='123456', db='test_db',
                              charset='utf8')
    # 获取游标
    cursor = connect.cursor()
    cursor.execute(sql)
    data=cursor.fetchall()    
    # 关闭连接
    cursor.close()
    connect.close()
    return data

# %%
data=get_cursor("SELECT DISTINCT area,CAST(`value` AS SIGNED INTEGER) `value` FROM farming WHERE product='猪肉' AND item='产量' AND time='2018' AND area!='全国' ORDER BY CAST(`value` AS SIGNED INTEGER) DESC limit 10")
print(data)
# Out:
# (('四川', 481), ('河南', 479), ('湖南', 446), ('山东', 421), ('湖北', 333), ('云南', 323), ('河北', 286), ('广东', 281), ('广西', 263), ('江西', 246))

# %%
x_tag = [i[0] for i in data]
y_val=[float(i[1]) for i in data]
print(x_tag)
print(y_val)
data=list(data)
print(data)
# Out:
# ['四川', '河南', '湖南', '山东', '湖北', '云南', '河北', '广东', '广西', '江西']
# [481.0, 479.0, 446.0, 421.0, 333.0, 323.0, 286.0, 281.0, 263.0, 246.0]
# [('四川', 481), ('河南', 479), ('湖南', 446), ('山东', 421), ('湖北', 333), ('云南', 323), ('河北', 286), ('广东', 281), ('广西', 263), ('江西', 246)]

# %%
name = x_tag
sales = y_val
bar = (
        Bar()
        .add_xaxis(x_tag)
        .add_yaxis("成交量", y_val)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="生猪产量top10柱形图"),
        )
        .reversal_axis() # 添加此句变为条形图
        .set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值"),])
        )
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5a5d6b8e54cf4bec9c30d593138d54f3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5a5d6b8e54cf4bec9c30d593138d54f3 = echarts.init(
#                     document.getElementById('5a5d6b8e54cf4bec9c30d593138d54f3'), 'white', {renderer: 'canvas'});
#                 var option_5a5d6b8e54cf4bec9c30d593138d54f3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6210\u4ea4\u91cf",
#             "data": [
#                 481.0,
#                 479.0,
#                 446.0,
#                 421.0,
#                 333.0,
#                 323.0,
#                 286.0,
#                 281.0,
#                 263.0,
#                 246.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6210\u4ea4\u91cf"
#             ],
#             "selected": {
#                 "\u6210\u4ea4\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u56db\u5ddd",
#                 "\u6cb3\u5357",
#                 "\u6e56\u5357",
#                 "\u5c71\u4e1c",
#                 "\u6e56\u5317",
#                 "\u4e91\u5357",
#                 "\u6cb3\u5317",
#                 "\u5e7f\u4e1c",
#                 "\u5e7f\u897f",
#                 "\u6c5f\u897f"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u751f\u732a\u4ea7\u91cftop10\u67f1\u5f62\u56fe"
#         }
#     ]
# };
#                 chart_5a5d6b8e54cf4bec9c30d593138d54f3.setOption(option_5a5d6b8e54cf4bec9c30d593138d54f3);
#         });
#     </script>

# %%
data1=get_cursor("SELECT DISTINCT area,CAST(`value` AS SIGNED INTEGER) `value` FROM farming WHERE product='猪肉' AND item='产量' AND time='2018' AND area!='全国' ORDER BY CAST(`value` AS SIGNED INTEGER) DESC")
print(data1)
# Out:
# (('四川', 481), ('河南', 479), ('湖南', 446), ('山东', 421), ('湖北', 333), ('云南', 323), ('河北', 286), ('广东', 281), ('广西', 263), ('江西', 246), ('安徽', 243), ('辽宁', 210), ('江苏', 205), ('贵州', 164), ('黑龙江', 149), ('重庆', 132), ('吉林', 127), ('福建', 113), ('陕西', 86), ('浙江', 74), ('内蒙古', 71), ('山西', 62), ('甘肃', 50), ('海南', 45), ('新疆', 38), ('天津', 21), ('北京', 13), ('上海', 11), ('青海', 9), ('宁夏', 8), ('西藏', 1))

# %%
data1 =list(data1)
def map_china() -> Map:
  c = (
    Map()
    .add(series_name="生猪产量(万吨)", data_pair=data1, maptype="china",zoom = 1,center=[105,38])
    .set_global_opts(
      title_opts=opts.TitleOpts(title="全国生猪产量地图"),
      visualmap_opts=opts.VisualMapOpts(max_=9999,is_piecewise=True,
              pieces=[{"max": 9, "min": 0, "label": "0-9","color":"#FFE4E1"},
                  {"max": 99, "min": 10, "label": "10-99","color":"#FF7F50"},
                  {"max": 499, "min": 100, "label": "100-499","color":"#F08080"},
                  {"max": 999, "min": 500, "label": "500-999","color":"#CD5C5C"},
                  {"max": 9999, "min": 1000, "label": ">=1000", "color":"#8B0000"}]
                       )
    )
  )
  return c
 
d_map = map_china()
d_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8980e7db046a477d9bb32e4bfba36a13" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8980e7db046a477d9bb32e4bfba36a13 = echarts.init(
#                     document.getElementById('8980e7db046a477d9bb32e4bfba36a13'), 'white', {renderer: 'canvas'});
#                 var option_8980e7db046a477d9bb32e4bfba36a13 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u751f\u732a\u4ea7\u91cf(\u4e07\u5428)",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 481
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 479
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 446
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 421
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 333
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 323
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 286
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 281
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 263
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 246
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 243
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 210
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 205
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 164
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 127
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 74
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "center": [
#                 105,
#                 38
#             ],
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u751f\u732a\u4ea7\u91cf(\u4e07\u5428)"
#             ],
#             "selected": {
#                 "\u751f\u732a\u4ea7\u91cf(\u4e07\u5428)": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5168\u56fd\u751f\u732a\u4ea7\u91cf\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 9999,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "max": 9,
#                 "min": 0,
#                 "label": "0-9",
#                 "color": "#FFE4E1"
#             },
#             {
#                 "max": 99,
#                 "min": 10,
#                 "label": "10-99",
#                 "color": "#FF7F50"
#             },
#             {
#                 "max": 499,
#                 "min": 100,
#                 "label": "100-499",
#                 "color": "#F08080"
#             },
#             {
#                 "max": 999,
#                 "min": 500,
#                 "label": "500-999",
#                 "color": "#CD5C5C"
#             },
#             {
#                 "max": 9999,
#                 "min": 1000,
#                 "label": ">=1000",
#                 "color": "#8B0000"
#             }
#         ]
#     }
# };
#                 chart_8980e7db046a477d9bb32e4bfba36a13.setOption(option_8980e7db046a477d9bb32e4bfba36a13);
#         });
#     </script>

# %%
data11=get_cursor("SELECT aa.*,bb.stage FROM (SELECT DISTINCT CAST(`value` AS SIGNED INTEGER) `value`,area FROM farming WHERE item='数量'"+ 
"AND area!='全国' AND time='2018' AND product='畜禽本期出栏数_猪') aa INNER JOIN "+
"(SELECT DISTINCT CAST(`value` AS SIGNED INTEGER) stage,area FROM farming WHERE item='数量' "+
"AND area!='全国' AND time='2018' AND product='畜禽存栏数(年末数)_猪')bb ON aa.area=bb.area")
print(data11)
# Out:
# ((169, '北京', 45), (278, '天津', 196), (3709, '河北', 1820), (814, '山西', 549), (896, '内蒙古', 497), (2495, '辽宁', 1262), (1570, '吉林', 870), (1964, '黑龙江', 1353), (148, '上海', 96), (2680, '江苏', 1552), (911, '浙江', 516), (2837, '安徽', 1356), (1421, '福建', 799), (3124, '江西', 1587), (5082, '山东', 2985), (6402, '河南', 4337), (4363, '湖北', 2521), (5993, '湖南', 3822), (3757, '广东', 2024), (3465, '广西', 2298), (561, '海南', 382), (1758, '重庆', 1167), (6638, '四川', 4258))

# %%
date = [i[1] for i in data11]
sales1 = [i[0] for i in data11]
sales2 = [i[2] for i in data11]
line = (
        Line()
        .add_xaxis(date)
        .add_yaxis("出栏数",sales1,
            markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average",name="平均值")]),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值")],symbol="diamond",symbol_size=30),  
        )
        .add_yaxis(
            "存栏数",sales2,
            markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average",name="平均值")]),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值")],),  
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="2018年生猪存栏与出栏折线图"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="587b1fa4adf249bb899e2494045b4df9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_587b1fa4adf249bb899e2494045b4df9 = echarts.init(
#                     document.getElementById('587b1fa4adf249bb899e2494045b4df9'), 'white', {renderer: 'canvas'});
#                 var option_587b1fa4adf249bb899e2494045b4df9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u51fa\u680f\u6570",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5317\u4eac",
#                     169
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     278
#                 ],
#                 [
#                     "\u6cb3\u5317",
#                     3709
#                 ],
#                 [
#                     "\u5c71\u897f",
#                     814
#                 ],
#                 [
#                     "\u5185\u8499\u53e4",
#                     896
#                 ],
#                 [
#                     "\u8fbd\u5b81",
#                     2495
#                 ],
#                 [
#                     "\u5409\u6797",
#                     1570
#                 ],
#                 [
#                     "\u9ed1\u9f99\u6c5f",
#                     1964
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     148
#                 ],
#                 [
#                     "\u6c5f\u82cf",
#                     2680
#                 ],
#                 [
#                     "\u6d59\u6c5f",
#                     911
#                 ],
#                 [
#                     "\u5b89\u5fbd",
#                     2837
#                 ],
#                 [
#                     "\u798f\u5efa",
#                     1421
#                 ],
#                 [
#                     "\u6c5f\u897f",
#                     3124
#                 ],
#                 [
#                     "\u5c71\u4e1c",
#                     5082
#                 ],
#                 [
#                     "\u6cb3\u5357",
#                     6402
#                 ],
#                 [
#                     "\u6e56\u5317",
#                     4363
#                 ],
#                 [
#                     "\u6e56\u5357",
#                     5993
#                 ],
#                 [
#                     "\u5e7f\u4e1c",
#                     3757
#                 ],
#                 [
#                     "\u5e7f\u897f",
#                     3465
#                 ],
#                 [
#                     "\u6d77\u5357",
#                     561
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     1758
#                 ],
#                 [
#                     "\u56db\u5ddd",
#                     6638
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "symbol": "diamond",
#                 "symbolSize": 30,
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     }
#                 ]
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5b58\u680f\u6570",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "\u5317\u4eac",
#                     45
#                 ],
#                 [
#                     "\u5929\u6d25",
#                     196
#                 ],
#                 [
#                     "\u6cb3\u5317",
#                     1820
#                 ],
#                 [
#                     "\u5c71\u897f",
#                     549
#                 ],
#                 [
#                     "\u5185\u8499\u53e4",
#                     497
#                 ],
#                 [
#                     "\u8fbd\u5b81",
#                     1262
#                 ],
#                 [
#                     "\u5409\u6797",
#                     870
#                 ],
#                 [
#                     "\u9ed1\u9f99\u6c5f",
#                     1353
#                 ],
#                 [
#                     "\u4e0a\u6d77",
#                     96
#                 ],
#                 [
#                     "\u6c5f\u82cf",
#                     1552
#                 ],
#                 [
#                     "\u6d59\u6c5f",
#                     516
#                 ],
#                 [
#                     "\u5b89\u5fbd",
#                     1356
#                 ],
#                 [
#                     "\u798f\u5efa",
#                     799
#                 ],
#                 [
#                     "\u6c5f\u897f",
#                     1587
#                 ],
#                 [
#                     "\u5c71\u4e1c",
#                     2985
#                 ],
#                 [
#                     "\u6cb3\u5357",
#                     4337
#                 ],
#                 [
#                     "\u6e56\u5317",
#                     2521
#                 ],
#                 [
#                     "\u6e56\u5357",
#                     3822
#                 ],
#                 [
#                     "\u5e7f\u4e1c",
#                     2024
#                 ],
#                 [
#                     "\u5e7f\u897f",
#                     2298
#                 ],
#                 [
#                     "\u6d77\u5357",
#                     382
#                 ],
#                 [
#                     "\u91cd\u5e86",
#                     1167
#                 ],
#                 [
#                     "\u56db\u5ddd",
#                     4258
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },

# %%
data2=get_cursor("SELECT DISTINCT time,CAST(`value` AS SIGNED INTEGER) `value` FROM farming WHERE product='猪肉' AND item='批发价' ORDER BY time")
print(data2)
# Out:
# (('201844', 19), ('201845', 19), ('201846', 19), ('201847', 19), ('201848', 19), ('201849', 19), ('201850', 19), ('201851', 19), ('201852', 19), ('201901', 25), ('201902', 19), ('201903', 18), ('201904', 18), ('201905', 17), ('201906', 18), ('201907', 18), ('201908', 18), ('201909', 18), ('201910', 18), ('201911', 19), ('201912', 20), ('201913', 20), ('201914', 20), ('201915', 20), ('201916', 20), ('201917', 20), ('201918', 20), ('201919', 20), ('201920', 20), ('201921', 20), ('201922', 20), ('201923', 21), ('201924', 21), ('201925', 21), ('201926', 22), ('201927', 22), ('201928', 23), ('201929', 23), ('201930', 24), ('201931', 24), ('201932', 25), ('201933', 27), ('201934', 30), ('201935', 33), ('201936', 34), ('201937', 35), ('201938', 36), ('201939', 36), ('201940', 36), ('201941', 40), ('201942', 45), ('201943', 50), ('201944', 52), ('201945', 51), ('201946', 48), ('201947', 43), ('201948', 42), ('201949', 43), ('201950', 43), ('201951', 43), ('201952', 43), ('202001', 44), ('202002', 45), ('202003', 46), ('202004', 47), ('202005', 49), ('202006', 49), ('202007', 50), ('202008', 50), ('202009', 49), ('202010', 48), ('202011', 48), ('202012', 47), ('202013', 47), ('202014', 46), ('202015', 45), ('202016', 44), ('202017', 44), ('202018', 43), ('202019', 42), ('202020', 40), ('202021', 39), ('202022', 38), ('202023', 39), ('202024', 40), ('202025', 42), ('202026', 44), ('202027', 45), ('202028', 47), ('202029', 48), ('202030', 48), ('202031', 48), ('202032', 48), ('202033', 48), ('202034', 48), ('202035', 48), ('202036', 48), ('202037', 47), ('202038', 47), ('202039', 47))

# %%
x_tag2 = [i[0] for i in data2]
y_val2=[i[1] for i in data2]
line = (
        Line()
        .add_xaxis(x_tag2)
        .add_yaxis("批发价",y_val2,
            markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(type_="average",name="平均值")]),
            markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max",name="最大值"),opts.MarkPointItem(type_="min",name="最小值")],symbol="diamond",symbol_size=30),  
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="全国平均猪肉价格走势"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        )
    )
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a71e51344056498e973a968140d3bfe7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a71e51344056498e973a968140d3bfe7 = echarts.init(
#                     document.getElementById('a71e51344056498e973a968140d3bfe7'), 'white', {renderer: 'canvas'});
#                 var option_a71e51344056498e973a968140d3bfe7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6279\u53d1\u4ef7",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "201844",
#                     19
#                 ],
#                 [
#                     "201845",
#                     19
#                 ],
#                 [
#                     "201846",
#                     19
#                 ],
#                 [
#                     "201847",
#                     19
#                 ],
#                 [
#                     "201848",
#                     19
#                 ],
#                 [
#                     "201849",
#                     19
#                 ],
#                 [
#                     "201850",
#                     19
#                 ],
#                 [
#                     "201851",
#                     19
#                 ],
#                 [
#                     "201852",
#                     19
#                 ],
#                 [
#                     "201901",
#                     25
#                 ],
#                 [
#                     "201902",
#                     19
#                 ],
#                 [
#                     "201903",
#                     18
#                 ],
#                 [
#                     "201904",
#                     18
#                 ],
#                 [
#                     "201905",
#                     17
#                 ],
#                 [
#                     "201906",
#                     18
#                 ],
#                 [
#                     "201907",
#                     18
#                 ],
#                 [
#                     "201908",
#                     18
#                 ],
#                 [
#                     "201909",
#                     18
#                 ],
#                 [
#                     "201910",
#                     18
#                 ],
#                 [
#                     "201911",
#                     19
#                 ],
#                 [
#                     "201912",
#                     20
#                 ],
#                 [
#                     "201913",
#                     20
#                 ],
#                 [
#                     "201914",
#                     20
#                 ],
#                 [
#                     "201915",
#                     20
#                 ],
#                 [
#                     "201916",
#                     20
#                 ],
#                 [
#                     "201917",
#                     20
#                 ],
#                 [
#                     "201918",
#                     20
#                 ],
#                 [
#                     "201919",
#                     20
#                 ],
#                 [
#                     "201920",
#                     20
#                 ],
#                 [
#                     "201921",
#                     20
#                 ],
#                 [
#                     "201922",
#                     20
#                 ],
#                 [
#                     "201923",
#                     21
#                 ],
#                 [
#                     "201924",
#                     21
#                 ],
#                 [
#                     "201925",
#                     21
#                 ],
#                 [
#                     "201926",
#                     22
#                 ],
#                 [
#                     "201927",
#                     22
#                 ],
#                 [
#                     "201928",
#                     23
#                 ],
#                 [
#                     "201929",
#                     23
#                 ],
#                 [
#                     "201930",
#                     24
#                 ],
#                 [
#                     "201931",
#                     24
#                 ],
#                 [
#                     "201932",
#                     25
#                 ],
#                 [
#                     "201933",
#                     27
#                 ],
#                 [
#                     "201934",
#                     30
#                 ],
#                 [
#                     "201935",
#                     33
#                 ],
#                 [
#                     "201936",
#                     34
#                 ],
#                 [
#                     "201937",
#                     35
#                 ],
#                 [
#                     "201938",
#                     36
#                 ],
#                 [
#                     "201939",
#                     36
#                 ],
#                 [
#                     "201940",
#                     36
#                 ],
#                 [
#                     "201941",
#                     40
#                 ],
#                 [
#                     "201942",
#                     45
#                 ],
#                 [
#                     "201943",
#                     50
#                 ],
#                 [
#                     "201944",
#                     52
#                 ],
#                 [
#                     "201945",
#                     51
#                 ],
#                 [
#                     "201946",
#                     48
#                 ],
#                 [
#                     "201947",
#                     43
#                 ],
#                 [
#                     "201948",
#                     42
#                 ],
#                 [
#                     "201949",
#                     43
#                 ],
#                 [
#                     "201950",
#                     43
#                 ],
#                 [
#                     "201951",
#                     43
#                 ],
#                 [
#                     "201952",
#                     43
#                 ],
#                 [
#                     "202001",
#                     44
#                 ],
#                 [
#                     "202002",
#                     45
#                 ],
#                 [
#                     "202003",
#                     46
#                 ],
#                 [
#                     "202004",
#                     47
#                 ],
#                 [
#                     "202005",
#                     49
#                 ],
#                 [
#                     "202006",
#                     49
#                 ],
#                 [
#                     "202007",
#                     50
#                 ],
#                 [
#                     "202008",
#                     50
#                 ],
#                 [
#                     "202009",
#                     49
#                 ],
#                 [
#                     "202010",
#                     48
#                 ],
#                 [
#                     "202011",

# %%
data3=get_cursor("SELECT item,count(*) FROM farming GROUP BY item")
print(data3)
# Out:
# (('产量', 7309), ('容积', 10), ('容量', 22), ('批发价', 500), ('拥有量', 87), ('播种面积', 1618), ('数量', 2110), ('金额', 28), ('销售量', 220), ('销售额', 232), ('面积', 988))

# %%
keyword = [i[0] for i in data3]
count = [i[1] for i in data3]
wordcloud = (
        WordCloud()
        .add("", [(k,c) for k,c in zip(keyword,count)] ,
             shape='star', rotate_step=20,
            )
        .set_global_opts(title_opts=opts.TitleOpts(title="农业数据标签统计"))
)
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="d6989bc8b6cc4f1181d499a3f5140245" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_d6989bc8b6cc4f1181d499a3f5140245 = echarts.init(
#                     document.getElementById('d6989bc8b6cc4f1181d499a3f5140245'), 'white', {renderer: 'canvas'});
#                 var option_d6989bc8b6cc4f1181d499a3f5140245 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 20,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u4ea7\u91cf",
#                     "value": 7309,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,111,125)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bb9\u79ef",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,41,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bb9\u91cf",
#                     "value": 22,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,21,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6279\u53d1\u4ef7",
#                     "value": 500,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,50,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62e5\u6709\u91cf",
#                     "value": 87,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,25,94)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u64ad\u79cd\u9762\u79ef",
#                     "value": 1618,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,79,98)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6570\u91cf",
#                     "value": 2110,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,34,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91d1\u989d",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,147,158)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9500\u552e\u91cf",
#                     "value": 220,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,18,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9500\u552e\u989d",
#                     "value": 232,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,109,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9762\u79ef",
#                     "value": 988,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,95,26)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u519c\u4e1a\u6570\u636e\u6807\u7b7e\u7edf\u8ba1"
#         }
#     ]
# };
#                 chart_d6989bc8b6cc4f1181d499a3f5140245.setOption(option_d6989bc8b6cc4f1181d499a3f5140245);
#         });
#     </script>

# %%
data4=get_cursor("SELECT product,count(*) FROM farming GROUP BY product")
print(data4)
# Out:
# (('中国兰花', 12), ('中国兰花种植', 6), ('中稻和一季晚稻', 73), ('主要盆景', 12), ('主要盆景种植', 6), ('主要盆栽植物', 14), ('主要盆栽植物种植', 7), ('主要鲜切花', 14), ('主要鲜切花种植', 7), ('亚麻', 20), ('人均棉花', 42), ('人均水产品', 110), ('人均油料', 48), ('人均粮食', 46), ('人均糖料', 10), ('传统渔民', 15), ('全年屠宰', 20), ('兰花类', 14), ('兰花类种植', 7), ('其他农作物', 10), ('其他茶', 13), ('其他谷物', 74), ('其它园林水果', 30), ('养殖_其他类', 7), ('养殖_甲壳类', 7), ('养殖_藻类', 7), ('养殖_贝类', 7), ('养殖_鱼类', 7), ('养殖水产品', 109), ('冬小麦', 68), ('凤梨类', 14), ('凤梨类种植', 7), ('剑麻番麻(折纤维)', 7), ('剑麻番麻(折纤维)实有', 7), ('剑麻番麻(折纤维)收获', 7), ('剑麻番麻(折纤维)新植', 7), ('半细羊毛', 13), ('南美白对虾', 9), ('双季晚稻', 16), ('向日葵籽', 50), ('咖啡豆(按干咖啡豆计算)', 7), ('咖啡豆(按干咖啡豆计算)实有', 7), ('咖啡豆(按干咖啡豆计算)收获', 7), ('咖啡豆(按干咖啡豆计算)新植', 7), ('唐菖蒲', 14), ('唐菖蒲种植', 7), ('园林水果', 30), ('国光苹果', 30), ('夏粮', 88), ('大豆', 95), ('大麦', 34), ('大麻(线麻)', 20), ('大黄鱼', 7), ('奶类', 146), ('家禽出栏', 69), ('小型屠宰点屠宰', 18), ('小麦', 106), ('屠宰企业', 20), ('山羊毛', 13), ('工业及其他用途花卉', 14), ('工业及其他用途花卉种植', 7), ('干燥花', 7), ('干燥花种植', 6), ('扣蟹', 9), ('投放鱼种', 10), ('捕捞', 46), ('捕捞_其他类', 7), ('捕捞_头足类', 7), ('捕捞_甲壳类', 7), ('捕捞_藻类', 7), ('捕捞_贝类', 7), ('捕捞_鱼类', 7), ('早稻', 20), ('春小麦', 57), ('机动渔船', 15), ('机动渔船_海洋渔业', 12), ('杜鹃花类', 14), ('杜鹃花类种植', 7), ('果园', 47), ('柑', 7), ('柑桔', 10), ('柑桔园', 10), ('柚', 7), ('柞蚕茧', 10), ('柿子', 44), ('桃', 30), ('桃园', 29), ('桑蚕茧', 10), ('桔', 7), ('梨', 46), ('梨园', 42), ('棉花', 125), ('椰子(按果实计算)', 7), ('椰子(按果实计算)实有', 7), ('椰子(按果实计算)收获', 7), ('椰子(按果实计算)新植', 7), ('橙', 7), ('橡胶(按干胶片计算)', 7), ('橡胶(按干胶片计算)实有', 7), ('橡胶(按干胶片计算)收获', 7), ('橡胶(按干胶片计算)新植', 7), ('水产养殖', 44), ('水产冷库', 16), ('水产冷库冷藏能力', 15), ('水产冷库冻结能力', 16), ('水产冷库制冰能力', 15), ('水产加工企业', 16), ('水产加工品_其他水产加工品', 16), ('水产加工品_冷冻加工品', 17), ('水产加工品_冷冻品', 19), ('水产加工品_助剂和添加剂', 8), ('水产加工品_干腌制品', 5), ('水产加工品_水产冷冻品', 20), ('水产加工品_水产饲料(鱼粉)', 13), ('水产加工品_海水加工', 18), ('水产加工品_淡水加工', 20), ('水产加工品_珍珠', 5), ('水产加工品_罐制品', 10), ('水产加工品_藻类加工品', 5), ('水产加工品_鱼油制品', 10), ('水产加工品_鱼糜制品', 9), ('水产加工品总量', 20), ('水产加工能力', 16), ('水产品', 109), ('河蟹育苗', 9), ('油料', 117), ('油菜籽', 74), ('海参', 8), ('海带育苗', 7), ('海水产品', 62), ('海水养殖', 27), ('海水养殖_中国对虾', 18), ('海水养殖_其他', 16), ('海水养殖_其他类', 15), ('海水养殖_军曹鱼', 7), ('海水养殖_南美白对虾', 21), ('海水养殖_吊笼', 2), ('海水养殖_大黄鱼', 7), ('海水养殖_工厂化', 15), ('海水养殖_底播', 2), ('海水养殖_扇贝', 14), ('海水养殖_斑节对虾', 8), ('海水养殖_日本对虾', 13), ('海水养殖_日本虾', 1), ('海水养殖_普通网箱', 7), ('海水养殖_梭子蟹', 15), ('海水养殖_江姚', 1), ('海水养殖_江珧', 7), ('海水养殖_江蓠', 8), ('海水养殖_池塘', 2), ('海水养殖_河鲀', 18), ('海水养殖_海上', 10), ('海水养殖_海参', 14), ('海水养殖_海带', 9), ('海水养殖_海水珍珠', 8), ('海水养殖_海胆', 8), ('海水养殖_海蜇', 13), ('海水养殖_深水网箱', 7), ('海水养殖_滩涂', 10), ('海水养殖_牡蛎', 11), ('海水养殖_甲壳类', 21), ('海水养殖_石斑鱼', 13), ('海水养殖_筏式', 2), ('海水养殖_紫菜', 8), ('海水养殖_羊栖菜', 3), ('海水养殖_美国红鱼', 14), ('海水养殖_苔菜', 3), ('海水养殖_藻类', 8), ('海水养殖_虾', 21), ('海水养殖_蚶', 14), ('海水养殖_蛏', 9), ('海水养殖_蛤', 14), ('海水养殖_螺', 13), ('海水养殖_蟹', 15), ('海水养殖_裙带菜', 9), ('海水养殖_贝类', 14), ('海水养殖_贻贝', 14), ('海水养殖_青蟹', 9), ('海水养殖_鰤鱼', 7), ('海水养殖_鱼类', 21), ('海水养殖_鲆鱼', 19), ('海水养殖_鲈鱼', 17), ('海水养殖_鲍', 9), ('海水养殖_鲷鱼', 12), ('海水养殖_鲽鱼', 17), ('海水养殖_麒麟菜', 8), ('海水养殖产品', 50), ('海水鱼苗', 9), ('海洋捕捞', 30), ('海洋捕捞_东海', 2), ('海洋捕捞_乌贼', 3), ('海洋捕捞_其他渔具', 4), ('海洋捕捞_其他类', 18), ('海洋捕捞_刺网', 4), ('海洋捕捞_南海', 2), ('海洋捕捞_围网', 4), ('海洋捕捞_大黄鱼', 2), ('海洋捕捞_头足类', 18), ('海洋捕捞_对虾', 19), ('海洋捕捞_小黄鱼', 18), ('海洋捕捞_带鱼', 19), ('海洋捕捞_张网', 4), ('海洋捕捞_拖网', 4), ('海洋捕捞_方头鱼', 2), ('海洋捕捞_梅童鱼', 3), ('海洋捕捞_梭子蟹', 18), ('海洋捕捞_梭鱼', 4), ('海洋捕捞_毛虾', 19), ('海洋捕捞_沙丁鱼', 7), ('海洋捕捞_海蜇', 16), ('海洋捕捞_海鳗', 7), ('海洋捕捞_渤海', 4), ('海洋捕捞_玉筋鱼', 3), ('海洋捕捞_甲壳类', 19), ('海洋捕捞_白姑鱼', 2), ('海洋捕捞_石斑鱼', 13), ('海洋捕捞_章鱼', 17), ('海洋捕捞_竹荚鱼', 2), ('海洋捕捞_蓝圆鯵', 5), ('海洋捕捞_蓝圆鲹', 2), ('海洋捕捞_藻类', 7), ('海洋捕捞_虾', 19), ('海洋捕捞_虾蛄', 2), ('海洋捕捞_蟹', 19), ('海洋捕捞_贝类', 18), ('海洋捕捞_金枪鱼', 7), ('海洋捕捞_金线鱼', 7), ('海洋捕捞_钓具', 2), ('海洋捕捞_青蟹', 3), ('海洋捕捞_马面鲀', 3), ('海洋捕捞_鮸鱼', 2), ('海洋捕捞_鱼类', 18), ('海洋捕捞_鱿鱼', 17), ('海洋捕捞_鲅鱼', 17), ('海洋捕捞_鲐鱼', 19), ('海洋捕捞_鲟', 2), ('海洋捕捞_鲱鱼', 2), ('海洋捕捞_鲳鱼', 14), ('海洋捕捞_鲷', 2), ('海洋捕捞_鲻鱼', 3), ('海洋捕捞_鳀鱼', 18), ('海洋捕捞_鳓鱼', 2), ('海洋捕捞_鹰爪虾', 13), ('海洋捕捞_黄姑鱼', 2), ('海洋捕捞_黄海', 4), ('海洋渔业专业从业人员', 14), ('海洋渔业专业从业人员_其他', 13), ('海洋渔业专业从业人员_养殖', 11), ('海洋渔 ...

# %%
keyword1 = [i[0] for i in data4]
count1 = [i[1] for i in data4]
wordcloud = (
        WordCloud()
        .add("", [(k,c) for k,c in zip(keyword1,count1)] ,
             shape='star', rotate_step=20,
            )
        .set_global_opts(title_opts=opts.TitleOpts(title="农产品名词统计"))
)
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="a4b8167c42c342fd9c995e307c6f378f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_a4b8167c42c342fd9c995e307c6f378f = echarts.init(
#                     document.getElementById('a4b8167c42c342fd9c995e307c6f378f'), 'white', {renderer: 'canvas'});
#                 var option_a4b8167c42c342fd9c995e307c6f378f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "star",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 20,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u4e2d\u56fd\u5170\u82b1",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,60,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u5170\u82b1\u79cd\u690d",
#                     "value": 6,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,130,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u7a3b\u548c\u4e00\u5b63\u665a\u7a3b",
#                     "value": 73,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,69,117)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u76c6\u666f",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,96,157)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u76c6\u666f\u79cd\u690d",
#                     "value": 6,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,69,67)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u76c6\u683d\u690d\u7269",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,44,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u76c6\u683d\u690d\u7269\u79cd\u690d",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,76,8)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u9c9c\u5207\u82b1",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,151,54)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e3b\u8981\u9c9c\u5207\u82b1\u79cd\u690d",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,88,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e9a\u9ebb",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,111,69)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5747\u68c9\u82b1",
#                     "value": 42,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(47,105,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5747\u6c34\u4ea7\u54c1",
#                     "value": 110,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(72,2,55)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5747\u6cb9\u6599",
#                     "value": 48,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,14,124)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5747\u7cae\u98df",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,65,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5747\u7cd6\u6599",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,126,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f20\u7edf\u6e14\u6c11",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(85,9,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5168\u5e74\u5c60\u5bb0",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(111,133,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u82b1\u7c7b",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,82,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5170\u82b1\u7c7b\u79cd\u690d",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,35,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u519c\u4f5c\u7269",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(119,35,148)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5176\u4ed6\u8336",
#                     "value": 13,
#                     "textStyle": {
#                         "normal": {
#                             "c
