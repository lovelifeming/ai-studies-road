# %%
import pandas as pd
import matplotlib.pyplot as plt
import mpl_finance as mpf
import numpy as np
#分析上证指数 数据

# %%
df=pd.read_csv('D:/Program Files/收藏/笔记/量化投资/上证指数000001.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7122 entries, 0 to 7121
# Data columns (total 12 columns):
# date             7122 non-null object
# code             7122 non-null object
# name             7122 non-null object
# closingPrice     7122 non-null float64
# topPrice         7122 non-null float64
# bottomPrice      7122 non-null float64
# openingPrice     7122 non-null float64
# beforeClosing    7122 non-null object
# changeAmount     7122 non-null object
# priceLimit       7122 non-null object
# turnover         7122 non-null int64
# tradingVolume    7122 non-null object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 667.8+ KB

# %%
df['ndate']=pd.to_datetime(df.date)
df['month']=df.ndate.apply(lambda x:x.month)
df.head()
# 日期	股票代码	名称	收盘价	最高价	最低价	开盘价	前收盘	涨跌额	涨跌幅	换手率	成交量	成交金额	总市值	流通市值
# Out:
#         date     code  name  closingPrice   topPrice  bottomPrice  \
# 0  2020/2/10  '000001  上证指数     2890.4878  2891.8479    2851.0503
# 1   2020/2/7  '000001  上证指数     2875.9636  2875.9636    2838.7702
# 2   2020/2/6  '000001  上证指数     2866.5097  2876.5878    2807.6090
# 3   2020/2/5  '000001  上证指数     2818.0878  2842.7426    2778.8641
# 4   2020/2/4  '000001  上证指数     2783.2875  2786.1642    2685.2693
#
#    openingPrice beforeClosing changeAmount priceLimit   turnover  \
# 0     2860.4990     2875.9636      14.5242      0.505  294929784
# 1     2858.9324     2866.5097       9.4539     0.3298  309479642
# 2     2826.8851     2818.0878      48.4219     1.7183  316392142
# 3     2792.3713     2783.2875      34.8003     1.2503  309761823
# 4     2685.2693     2746.6056      36.6819     1.3355  364046200
#
#   tradingVolume      ndate  month
# 0      3.42E+11 2020-02-10      2
# 1      3.62E+11 2020-02-07      2
# 2      3.59E+11 2020-02-06      2
# 3      3.49E+11 2020-02-05      2
# 4      3.74E+11 2020-02-04      2

# %%
# df_1=df[df.month ==6][df.ndate>'2019-01-01']
df_1=df
fig,axl=plt.subplots(figsize=(20,20))
mpf.candlestick2_ohlc(axl,df_1.openingPrice.values,df_1.topPrice.values,df_1.bottomPrice.values,df_1.closingPrice.values,
                      width=1,colorup='b',colordown='r')
#显示均线
df['ma5']=df.openingPrice.rolling(window=5).mean()
df['ma30']=df.openingPrice.rolling(window=30).mean()
l=[i for i in range(df_1.date.count())]

# %%
plt.plot(df.date.values,df.closingPrice.values,color='red',linewidth=2.0,linestyle='--')
plt.plot(df.date.values,df.openingPrice.values,color='blue',linewidth=3.0,linestyle='-.')
plt.show()

# %%
da=np.asarray(df)
da
# Out:
# array([['2020/2/10', "'000001", '上证指数', ..., 2, nan, nan],
#        ['2020/2/7', "'000001", '上证指数', ..., 2, nan, nan],
#        ['2020/2/6', "'000001", '上证指数', ..., 2, nan, nan],
#        ...,
#        ['1990/12/21', "'000001", '上证指数', ..., 12, 118.6540000000062,
#         129.59333333333862],
#        ['1990/12/20', "'000001", '上证指数', ..., 12, 114.4600000000062,
#         128.75333333333865],
#        ['1990/12/19', "'000001", '上证指数', ..., 12, 108.6160000000062,
#         127.62400000000531]], dtype=object)
